# %% [markdown]
# # Node usage analysis with `sacct` output
#
# This notebook analyzes the node usage from the Slurm `sacct` output.
# The analysis includes:
# - Parsing the `AllocTRES` field to extract CPU, memory, and node information.
# - Calculating total node hours used and remaining.
# - Estimating running days for a given number of nodes.
# - Estimating the required nodes for specific remaining days.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load the `sacct` result
#
# The `sacct` command outputs job information. Below is the command used to generate the file:
#
# ```shell
# sacct -S 2024-10-01 -E 2024-12-18 --format="JOBID,JobName,Partition,State,AllocTres,ElapsedRaw -p -T" > sacct.txt
# ```

# %%
# Load the `sacct` result
info1 = pd.read_csv("./sacct-20241212.txt", delimiter="|")
info2 = pd.read_csv("./sacct-20241218.txt", delimiter="|")

# %% [markdown]
# ## Parse `AllocTRES` field
#
# Extract `cpu`, `mem`, and `node` information from the `AllocTRES` column and add them as new columns to the DataFrame.

# %%
def parse_AllocTRES(info):
    # Extract cpu, mem, and node from AllocTRES
    alloc_cols = info["AllocTRES"].str.extract(r'cpu=(\d+),mem=(\d+M),node=(\d+)')
    alloc_cols.columns = ["cpu", "mem", "node"]

    # Add the parsed data to the DataFrame
    return(pd.concat([info, alloc_cols], axis=1))

# %%
info1 = parse_AllocTRES(info1)
info2 = parse_AllocTRES(info2)

# %%
info1
# Out:
#                JobID      JobName  Partition               State  \
# 0           14775436  check_cores     normal           COMPLETED
# 1     14775436.batch        batch        NaN           COMPLETED
# 2    14775436.extern       extern        NaN           COMPLETED
# 3           14858548   hr5-016-01     normal           COMPLETED
# 4     14858548.batch        batch        NaN           COMPLETED
# ..               ...          ...        ...                 ...
# 185         15020763         CPL1  large_cpu  CANCELLED by 43801
# 186         15020836         LCDM  large_cpu  CANCELLED by 43801
# 187         15020838         CPL0  large_cpu  CANCELLED by 43801
# 188         15020842         CPL1  large_cpu  CANCELLED by 43801
# 189         15034844        LCDM4  large_cpu  CANCELLED by 43801
#
#                                       AllocTRES  ElapsedRaw  Unnamed: 6   cpu  \
# 0                       cpu=2,mem=14200M,node=1           2         NaN     2
# 1                       cpu=2,mem=14200M,node=1           2         NaN     2
# 2                       cpu=2,mem=14200M,node=1           2         NaN     2
# 3                     cpu=32,mem=227200M,node=1           4         NaN    32
# 4                     cpu=32,mem=227200M,node=1           4         NaN    32
# ..                                          ...         ...         ...   ...
# 185                                         NaN           0         NaN   NaN
# 186  billing=3024,cpu=4320,mem=7726620M,node=30           0         NaN  4320
# 187  billing=3024,cpu=4320,mem=7726620M,node=30           0         NaN  4320
# 188  billing=3024,cpu=4320,mem=7726620M,node=30           0         NaN  4320
# 189                                         NaN           0         NaN   NaN
#
#           mem node
# 0      14200M    1
# 1      14200M    1
# 2      14200M    1
# 3     227200M    1
# 4     227200M    1
# ..        ...  ...
# 185       NaN  NaN
# 186  7726620M   30
# 187  7726620M   30
# 188  7726620M   30
# 189       NaN  NaN
#
# [190 rows x 10 columns]

# %%
info2
# Out:
#                JobID         JobName  Partition      State  \
# 0           14775436     check_cores     normal  COMPLETED
# 1     14775436.batch           batch        NaN  COMPLETED
# 2    14775436.extern          extern        NaN  COMPLETED
# 3           14858548      hr5-016-01     normal  COMPLETED
# 4     14858548.batch           batch        NaN  COMPLETED
# ..               ...             ...        ...        ...
# 215       15126900.0  ramses-lcdm-3d        NaN    RUNNING
# 216         15126905            CPL1  large_cpu    RUNNING
# 217   15126905.batch           batch        NaN    RUNNING
# 218  15126905.extern          extern        NaN    RUNNING
# 219       15126905.0  ramses-cpl1-3d        NaN    RUNNING
#
#                                       AllocTRES  ElapsedRaw  Unnamed: 6   cpu  \
# 0                       cpu=2,mem=14200M,node=1           2         NaN     2
# 1                       cpu=2,mem=14200M,node=1           2         NaN     2
# 2                       cpu=2,mem=14200M,node=1           2         NaN     2
# 3                     cpu=32,mem=227200M,node=1           4         NaN    32
# 4                     cpu=32,mem=227200M,node=1           4         NaN    32
# ..                                          ...         ...         ...   ...
# 215               cpu=2400,mem=7726620M,node=30       25510         NaN  2400
# 216  billing=3024,cpu=4320,mem=7726620M,node=30       25450         NaN  4320
# 217                  cpu=144,mem=257554M,node=1       25450         NaN   144
# 218  billing=3024,cpu=4320,mem=7726620M,node=30       25450         NaN  4320
# 219               cpu=2400,mem=7726620M,node=30       25450         NaN  2400
#
#           mem node
# 0      14200M    1
# 1      14200M    1
# 2      14200M    1
# 3     227200M    1
# 4     227200M    1
# ..        ...  ...
# 215  7726620M   30
# 216  7726620M   30
# 217   257554M    1
# 218  7726620M   30
# 219  7726620M   30
#
# [220 rows x 10 columns]

# %%
info2[190:]
# Out:
#                JobID         JobName  Partition               State  \
# 190         15020838            CPL0  large_cpu  CANCELLED by 43801
# 191   15020838.batch           batch        NaN           CANCELLED
# 192  15020838.extern          extern        NaN           COMPLETED
# 193       15020838.0  ramses-cpl0-3d        NaN              FAILED
# 194         15020842            CPL1  large_cpu  CANCELLED by 43801
# 195   15020842.batch           batch        NaN           CANCELLED
# 196  15020842.extern          extern        NaN           COMPLETED
# 197       15020842.0  ramses-cpl1-3d        NaN              FAILED
# 198         15034844           LCDM4  large_cpu  CANCELLED by 43801
# 199         15065870            LCDM  large_cpu             TIMEOUT
# 200   15065870.batch           batch        NaN           CANCELLED
# 201  15065870.extern          extern        NaN           COMPLETED
# 202       15065870.0  ramses-lcdm-3d        NaN              FAILED
# 203         15106326            LCDM  large_cpu  CANCELLED by 43801
# 204         15124476            LCDM  large_cpu  CANCELLED by 43801
# 205   15124476.batch           batch        NaN           CANCELLED
# 206  15124476.extern          extern        NaN           COMPLETED
# 207       15124476.0  ramses-lcdm-3d        NaN              FAILED
# 208         15124479            CPL0  large_cpu             RUNNING
# 209   15124479.batch           batch        NaN             RUNNING
# 210  15124479.extern          extern        NaN             RUNNING
# 211       15124479.0  ramses-cpl0-3d        NaN             RUNNING
# 212         15126900            LCDM  large_cpu             RUNNING
# 213   15126900.batch           batch        NaN             RUNNING
# 214  15126900.extern          extern        NaN             RUNNING
# 215       15126900.0  ramses-lcdm-3d        NaN             RUNNING
# 216         15126905            CPL1  large_cpu             RUNNING
# 217   15126905.batch           batch        NaN             RUNNING
# 218  15126905.extern          extern        NaN             RUNNING
# 219       15126905.0  ramses-cpl1-3d        NaN             RUNNING
#
#                                       AllocTRES  ElapsedRaw  Unnamed: 6   cpu  \
# 190  billing=3024,cpu=4320,mem=7726620M,node=30      252085         NaN  4320
# 191                  cpu=144,mem=257554M,node=1      252086         NaN   144
# 192  billing=3024,cpu=4320,mem=7726620M,node=30      252085         NaN  4320
# 193               cpu=1200,mem=7726620M,node=30      252089         NaN  1200
# 194  billing=3024,cpu=4320,mem=7726620M,node=30      234289         NaN  4320
# 195                  cpu=144,mem=257554M,node=1      234290         NaN   144
# 196  billing=3024,cpu=4320,mem=7726620M,node=30      234289         NaN  4320
# 197               cpu=1200,mem=7726620M,node=30      234295         NaN  1200
# 198                                         NaN           0         NaN   NaN
# 199  billing=3024,cpu=4320,mem=7726620M,node=30       86419         NaN  4320
# 200                  cpu=144,mem=257554M,node=1       86420         NaN   144
# 201  billing=3024,cpu=4320,mem=7726620M,node=30       86419         NaN  4320
# 202               cpu=1200,mem=7726620M,node=30       86429         NaN  1200
# 203                                         NaN           0         NaN   NaN
# 204  billing=3024,cpu=4320,mem=7726620M,node=30      106303         NaN  4320
# 205                  cpu=144,mem=257554M,node=1      106304         NaN   144
# 206  billing=3024,cpu=4320,mem=7726620M,node=30      106303         NaN  4320
# 207               cpu=1200,mem=7726620M,node=30      106308         NaN  1200
# 208  billing=3024,cpu=4320,mem=7726620M,node=30      131039         NaN  4320
# 209                  cpu=144,mem=257554M,node=1      131039         NaN   144
# 210  billing=3024,cpu=4320,mem=7726620M,node=30      131039         NaN  4320
# 211               cpu=2400,mem=7726620M,node=30      131039         NaN  2400
# 212  billing=3024,cpu=4320,mem=7726620M,node=30       25511         NaN  4320
# 213                  cpu=144,mem=257554M,node=1       25511         NaN   144
# 214  billing=3024,cpu=4320,mem=7726620M,node=30       25511         NaN  4320
# 215               cpu=2400,mem=7726620M,node=30       25510         NaN  2400
# 216  billing=3024,cpu=4320,mem=7726620M,node=30       25450         NaN  4320
# 217                  cpu=144,mem=257554M,node=1       25450         NaN   144
# 218  billing=3024,cpu=4320,mem=7726620M,node=30       25450         NaN  4320
# 219               cpu=2400,mem=7726620M,node=30       25450         NaN  2400
#
#           mem node
# 190  7726620M   30
# 191   257554M    1
# 192  7726620M   30
# 193  7726620M   30
# 194  7726620M   30
# 195   257554M    1
# 196  7726620M   30
# 197  7726620M   30
# 198       NaN  NaN
# 199  7726620M   30
# 200   257554M    1
# 201  7726620M   30
# 202  7726620M   30
# 203       NaN  NaN
# 204  7726620M   30
# 205   257554M    1
# 206  7726620M   30
# 207  7726620M   30
# 208  7726620M   30
# 209   257554M    1
# 210  7726620M   30
# 211  7726620M   30
# 212  7726620M   30
# 213   257554M    1
# 214  7726620M   30
# 215  7726620M   30
# 216  7726620M   30
# 217   257554M    1
# 218  7726620M   30
# 219  7726620M   30

# %%
info2[0:220:3]
# Out:
#                JobID         JobName  Partition      State  \
# 0           14775436     check_cores     normal  COMPLETED
# 3           14858548      hr5-016-01     normal  COMPLETED
# 6         14858548.0        ramses3d        NaN  COMPLETED
# 9     14858550.batch           batch        NaN  COMPLETED
# 12          14858551      hr5-016-02     normal  COMPLETED
# ..               ...             ...        ...        ...
# 207       15124476.0  ramses-lcdm-3d        NaN     FAILED
# 210  15124479.extern          extern        NaN    RUNNING
# 213   15126900.batch           batch        NaN    RUNNING
# 216         15126905            CPL1  large_cpu    RUNNING
# 219       15126905.0  ramses-cpl1-3d        NaN    RUNNING
#
#                                       AllocTRES  ElapsedRaw  Unnamed: 6   cpu  \
# 0                       cpu=2,mem=14200M,node=1         2.0         NaN     2
# 3                     cpu=32,mem=227200M,node=1         4.0         NaN    32
# 6                     cpu=16,mem=113600M,node=1         4.0         NaN    16
# 9                     cpu=32,mem=227200M,node=1         4.0         NaN    32
# 12                    cpu=32,mem=227200M,node=1         2.0         NaN    32
# ..                                          ...         ...         ...   ...
# 207               cpu=1200,mem=7726620M,node=30    106308.0         NaN  1200
# 210  billing=3024,cpu=4320,mem=7726620M,node=30    131039.0         NaN  4320
# 213                  cpu=144,mem=257554M,node=1     25511.0         NaN   144
# 216  billing=3024,cpu=4320,mem=7726620M,node=30     25450.0         NaN  4320
# 219               cpu=2400,mem=7726620M,node=30     25450.0         NaN  2400
#
#           mem  node    NodeHours
# 0      14200M   1.0     0.000556
# 3     227200M   1.0     0.001111
# 6     113600M   1.0     0.001111
# 9     227200M   1.0     0.001111
# 12    227200M   1.0     0.000556
# ..        ...   ...          ...
# 207  7726620M  30.0   885.900000
# 210  7726620M  30.0  1091.991667
# 213   257554M   1.0     7.086389
# 216  7726620M  30.0   212.083333
# 219  7726620M  30.0   212.083333
#
# [74 rows x 11 columns]

# %% [markdown]
# ## Compute node hours

# %%
def add_node_hours(info):
    info["ElapsedRaw"] = info["ElapsedRaw"].astype(float)  # sec
    info["node"] = info["node"].astype(float)
    info["NodeHours"] = (info["ElapsedRaw"] * info["node"]) / 3600  # hr

# %%
add_node_hours(info1)
add_node_hours(info2)

# %%
node_hours_used1 = info1[info1['Partition']=='large_cpu']["NodeHours"].sum()
node_hours_used2 = info2[info2['Partition']=='large_cpu']["NodeHours"].sum()

# %%
node_hours_used2 - node_hours_used1 # node hours for final runs
# Out:
# 7196.800000000003

# %%
(node_hours_used2 - node_hours_used1)/24/30 # node days for final runs
# It gives 10 days, but it's more than 5+3+2?
# Out:
# 9.99555555555556

# %%
info2[info2['Partition']=='large_cpu']["NodeHours"].sum()
# Out:
# 14371.44166666667

# %%
node_hours_total = 63000 # total node hours available on Olaf
node_hours_used = info2[info2['Partition']=='large_cpu']["NodeHours"].sum() 
node_hours_left = node_hours_total - node_hours_used

print(f"Total node hours: {node_hours_total:10.2f} h")
print(f"Used node hours:  {node_hours_used:10.2f} h ({node_hours_used/node_hours_total*100:.2f}%)")
print(f"Left node hours:  {node_hours_left:10.2f} h ({node_hours_left/node_hours_total*100:.2f}%)")
# Out:
# Total node hours:   63000.00 h
# Used node hours:    14371.44 h (22.81%)
# Left node hours:    48628.56 h (77.19%)

# %% [markdown]
# ## Estimate remaining days for specific node usage

# %%
nodes = 90
days_left = node_hours_left / 24 / nodes
print(f"Running days with {nodes} nodes: {days_left:.2f} days")
# Out:
# Running days with 90 nodes: 22.51 days

# %% [markdown]
# ## Estimate required nodes for a specific remaining days

# %%
days_left = 30
nodes = node_hours_left / 24 / days_left
print(f"Required nodes for {days_left} days: {nodes:.2f} nodes")
# Out:
# Required nodes for 30 days: 67.54 nodes

# %% [markdown]
# # Estimate the number of maximum runs

# %%
# For one simulation,
nodes = 30
days_run = 20 # days (~ 10 days for ideal case?)
node_hours_run = nodes * days_run * 24

# %%
node_hours_total / node_hours_run
# Out:
# 4.375
